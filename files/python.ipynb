# %% [markdown]
# This is a simple Python notebook. Below we'll show off matplotlib plotting.

# %%
import os
from urllib.parse import parse_qs

params = parse_qs(os.environ.get("QUERY_STRING", ""))
dataset_url = params.get("dataset_url", ["https://example.com/default.csv"])[0]

print(f"Loading dataset from: {dataset_url}")

# %%
print(myvar)

# %%
x = 100 * np.random.rand(500)
y = 100 * np.random.rand(500)
areas = 1000 * np.random.rand(500)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(x, y, s=areas, c=areas, alpha=.5)

# %%
import ipyparams

# debug: see everything in the URL
print(dict(ipyparams.params))
