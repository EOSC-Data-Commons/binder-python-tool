# %% [markdown]
# ### Binder general python tool
#
# This is a tool for general purpose to interact with dataset from Eosc-data-common, visit https://matchmaker.eosc-data-commons.eu/.
#
# To staging the data:
#
# * Run the cell and wait for the widget to load
#
# * Click **Download Dataset** to download the dataset into the `data/` folder
#
# * Click **Show Files** to inspect the downloaded files in a tree view

# %%
from dataset_widget import datastaging_widget

datastaging_widget()
